# %%
import numpy as np
import pandas as pd

# %%
shark_tank=pd.read_excel('EDA_Shark_Tank_India.xlsx')

# %%
shark_tank.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
shark_tank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
shark_tank[(shark_tank["deal"]==1)&(shark_tank["deal_amount"]==0)]
# in this row deal is 1 but deal amount and all sharks deal is zero so in deal columns should be 0
# Out:
#     episode_number  pitch_number brand_name  \
# 19               7            20   Torch-it
#
#                                     idea  deal  pitcher_ask_amount  \
# 19  Gadgets for visually impaired people     1                75.0
#
#     ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 19         1.0         7500.0          0.0          0.0  ...             0
#
#     anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 19            0          0            0             0            0
#
#     ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 19            0                      0               0.0               0.0
#
# [1 rows x 28 columns]

# %%
shark_tank.loc[(shark_tank["deal"]==1)&(shark_tank["deal_amount"]==0),"deal"]=0

# %%
shark_tank[(shark_tank["deal"]==1)&(shark_tank["deal_amount"]==0)]
# Out:
# Empty DataFrame
# Columns: [episode_number, pitch_number, brand_name, idea, deal, pitcher_ask_amount, ask_equity, ask_valuation, deal_amount, deal_equity, deal_valuation, ashneer_present, anupam_present, aman_present, namita_present, vineeta_present, peyush_present, ghazal_present, ashneer_deal, anupam_deal, aman_deal, namita_deal, vineeta_deal, peyush_deal, ghazal_deal, total_sharks_invested, amount_per_shark, equity_per_shark]
# Index: []
#
# [0 rows x 28 columns]

# %%
shark_tank[(shark_tank["deal"]==0)&(shark_tank["deal_amount"]>0)]

#here deal is done but int deal colunms its showing 0
# Out:
#     episode_number  pitch_number          brand_name                   idea  \
# 18               7            19  Raising Superstars  Child Development App
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 18     0               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 18          4.0  ...             1            0          1            0
#
#     vineeta_deal  peyush_deal  ghazal_deal  total_sharks_invested  \
# 18             0            0            0                      2
#
#     amount_per_shark  equity_per_shark
# 18              50.0               2.0
#
# [1 rows x 28 columns]

# %%
shark_tank.loc[(shark_tank["deal"]==0)&(shark_tank["deal_amount"]>0),'deal']=1

# %%
shark_tank[(shark_tank["deal"]==0)&(shark_tank["deal_amount"]>0)]
# Out:
# Empty DataFrame
# Columns: [episode_number, pitch_number, brand_name, idea, deal, pitcher_ask_amount, ask_equity, ask_valuation, deal_amount, deal_equity, deal_valuation, ashneer_present, anupam_present, aman_present, namita_present, vineeta_present, peyush_present, ghazal_present, ashneer_deal, anupam_deal, aman_deal, namita_deal, vineeta_deal, peyush_deal, ghazal_deal, total_sharks_invested, amount_per_shark, equity_per_shark]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# #### Q1. Find the number of episodes?

# %%
shark_tank["episode_number"].nunique()
# Out:
# 35

# %% [markdown]
# #### Q2. Max, min , mean of asked amount,asked equity, asked valuation?

# %%
shark_tank[["pitcher_ask_amount","ask_equity","ask_valuation"]].agg({"max","min","mean"})
# Out:
#       pitcher_ask_amount  ask_equity  ask_valuation
# mean          319.854709    5.188034    3852.462479
# min             0.001010    0.250000       0.010000
# max         30000.000000   25.000000  120000.000000

# %% [markdown]
# #### Q3. Max & Min asked- equity,asked-valuation and asked amount episode-wise?

# %%
shark_tank.groupby("episode_number")[["pitcher_ask_amount","ask_equity","ask_valuation"]].agg({"max","min"})
# Out:
#                pitcher_ask_amount          ask_equity       ask_valuation  \
#                               min      max        min   max           min
# episode_number
# 1                        25.00000     50.0       5.00  15.0        250.00
# 2                        50.00000     70.0       1.00   5.0       1000.00
# 3                        50.00000    100.0       0.25   4.0       1875.00
# 4                        50.00000     75.0       4.00  10.0        500.00
# 5                        10.00000    100.0       1.00  20.0         50.00
# 6                        45.00000    100.0       1.00  10.0        500.00
# 7                        50.00000    100.0       1.00   7.5        666.67
# 8                        30.00000     56.0       2.50   7.5        746.67
# 9                        50.00000    100.0       2.50   5.0       1000.00
# 10                       25.00000     30.0       2.00   5.0        500.00
# ...

# %% [markdown]
# #### Q4. Brand names in which 2 ,3 or 4 sharks are invested?

# %%
shark_tank[(shark_tank["total_sharks_invested"]>1)&(shark_tank["total_sharks_invested"]<=4)][["brand_name","total_sharks_invested"]].reset_index(drop=True)
# Out:
#                         brand_name  total_sharks_invested
# 0              BluePine Industries                      3
# 1                    Booz scooters                      2
# 2              Heart up my Sleeves                      2
# 3                            Cosiq                      2
# 4                           Bummer                      2
# 5                      Revamp Moto                      2
# 6               Raising Superstars                      2
# 7                     Beyond Snack                      2
# 8   Vivalyf Innovations- Easy Life                      2
# 9                            Altor                      2
# 10                           Ariro                      2
# 11                         Nuutjob                      3
# 12                        Meatyour                      3
# 13                       EventBeep                      3
# 14                           Farda                      2
# ...

# %% [markdown]
# #### Q5. Episode wise minimum and maximum of sharks invested?

# %%
shark_tank.groupby("episode_number")["total_sharks_invested"].agg({'min','max'})
# Out:
#                 min  max
# episode_number
# 1                 2    3
# 2                 0    1
# 3                 0    1
# 4                 0    2
# 5                 0    2
# 6                 0    5
# 7                 0    2
# 8                 1    2
# 9                 0    2
# 10                3    3
# 11                0    2
# 12                0    3
# 13                2    4
# 14                0    2
# 15                1    3
# 16                0    2
# 17                0    5
# 18                0    1
# 19                0    4
# 20                0    5
# 21                1    3
# 22                0    3
# 23                0    1
# 24                0    2
# 25                0    5
# 26                0    1
# 27                0    4
# 28                0    3
# 29                0    3
# 30                0    2
# 31                0    1
# 32                0    1
# 33                0    3
# 34                0    4
# 35                0    4

# %% [markdown]
# #### Q6. Minimum and Maximum sharks invested in each episode?

# %%
shark_tank.groupby("episode_number")["total_sharks_invested"].agg({"min","max"})
# Out:
#                 min  max
# episode_number
# 1                 2    3
# 2                 0    1
# 3                 0    1
# 4                 0    2
# 5                 0    2
# 6                 0    5
# 7                 0    2
# 8                 1    2
# 9                 0    2
# 10                3    3
# 11                0    2
# 12                0    3
# 13                2    4
# 14                0    2
# 15                1    3
# 16                0    2
# 17                0    5
# 18                0    1
# 19                0    4
# 20                0    5
# 21                1    3
# 22                0    3
# 23                0    1
# 24                0    2
# 25                0    5
# 26                0    1
# 27                0    4
# 28                0    3
# 29                0    3
# 30                0    2
# 31                0    1
# 32                0    1
# 33                0    3
# 34                0    4
# 35                0    4

# %% [markdown]
# #### Q7. Brand names who ask for 1 crore and got a deal? ####

# %%
shark_tank[(shark_tank["pitcher_ask_amount"]==100)&(shark_tank["deal_amount"]==100)][["brand_name"]].reset_index().drop('index',axis=1)
# Out:
#             brand_name
# 0          Revamp Moto
# 1   Raising Superstars
# 2    The Renal Project
# 3           Get a Whey
# 4  Sunfox Technologies
# 5   Insurance Samadhan

# %% [markdown]
# #### Q8. Brand names where deal equity is between 0 to 50?

# %%
shark_tank[(shark_tank["deal_equity"]>0) & (shark_tank["deal_equity"]<50)][["brand_name","deal_equity"]]
# Out:
#               brand_name  deal_equity
# 0    BluePine Industries        16.00
# 2    Heart up my Sleeves        30.00
# 3             Tagz Foods         2.75
# 7              Peeschute         6.00
# 8                   NOCD        15.00
# ..                   ...          ...
# 106        Colour Me Mad        25.00
# 108           Tweek Labs        10.00
# 109               Proxgy        10.00
# 110   Nomad Food Project        20.00
# 114        Jain Shikanji        30.00
#
# [62 rows x 2 columns]

# %% [markdown]
# #### Q9. Find the number of brands participated in each episode?

# %%
shark_tank.groupby('episode_number')["brand_name"].nunique()
# Out:
# episode_number
# 1     3
# 2     3
# 3     3
# 4     3
# 5     3
# 6     3
# 7     3
# 8     3
# 9     3
# 10    3
# 11    3
# 12    3
# 13    3
# 14    3
# 15    3
# 16    4
# 17    4
# 18    4
# 19    4
# 20    3
# 21    3
# 22    4
# 23    4
# 24    3
# 25    3
# 26    3
# 27    4
# 28    3
# 29    3
# 30    4
# 31    4
# 32    4
# 33    4
# 34    4
# 35    3
# Name: brand_name, dtype: int64

# %% [markdown]
# #### Q10. How many sharks participated in this show and What were their names? ####

# %%
sharks=shark_tank.columns[shark_tank.columns.str.contains('present')==True].str.split('_')

# %%
sharks_name=[]
numberOfSharks=0;
for shark in sharks:
    sharks_name.append(shark[0])
    numberOfSharks+=1
    
print(f"Name of the Sharks:{sharks_name}")
print(f"Number of Sharks:{numberOfSharks}")
# Out:
# Name of the Sharks:['ashneer', 'anupam', 'aman', 'namita', 'vineeta', 'peyush', 'ghazal']
# Number of Sharks:7

# %% [markdown]
# #### Q11. Find appearance of each sharks?

# %%
shark_tank[['ashneer_present','anupam_present','aman_present','namita_present','vineeta_present','peyush_present','ghazal_present']].sum().sort_values(ascending=False)
# Out:
# anupam_present     117
# namita_present     106
# ashneer_present     98
# aman_present        98
# peyush_present      88
# vineeta_present     66
# ghazal_present      26
# dtype: int64

# %% [markdown]
# #### Q12. How many entrepreneurs were present?

# %%
shark_tank["pitch_number"].count()
# Out:
# 117

# %% [markdown]
# #### Q13. How many times each shark invested the deal?

# %%
shark_tank[['ashneer_deal','anupam_deal','aman_deal','namita_deal','vineeta_deal','peyush_deal','ghazal_deal']].sum().sort_values(ascending=False)
# Out:
# aman_deal       28
# peyush_deal     27
# anupam_deal     24
# namita_deal     22
# ashneer_deal    21
# vineeta_deal    15
# ghazal_deal      7
# dtype: int64

# %% [markdown]
# #### Q14. Find the equity percent that each sharks gets?

# %%
shark_tank.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
ashneer_equity=shark_tank[shark_tank["ashneer_deal"]==1]["equity_per_shark"].sum()
anupam_equity=shark_tank[shark_tank["anupam_deal"]==1]["equity_per_shark"].sum()
aman_equity=shark_tank[shark_tank["aman_deal"]==1]["equity_per_shark"].sum()
namita_equity=shark_tank[shark_tank["namita_deal"]==1]["equity_per_shark"].sum()
vineeta_equity=shark_tank[shark_tank["vineeta_deal"]==1]["equity_per_shark"].sum()
peyush_equity=shark_tank[shark_tank["peyush_deal"]==1]["equity_per_shark"].sum()
ghazal_equity=shark_tank[shark_tank["ghazal_deal"]==1]["equity_per_shark"].sum()

# %%
print(f"ashneer_equity_percentage:{ashneer_equity*100/Total_equity}")
print(f"anupam_equity_percentage:{anupam_equity*100/Total_equity}")
print(f"aman_equity_percentage:{aman_equity*100/Total_equity}")
print(f"namita_equity_percentage:{namita_equity*100/Total_equity}")
print(f"vineeta_equity_percentage:{vineeta_equity*100/Total_equity}")
print(f"peyush_equity_percentage:{peyush_equity*100/Total_equity}")
print(f"ghazal_equity_percentage:{ghazal_equity*100/Total_equity}")
# Out:
# ashneer_equity_percentage:8.891707112316801
# anupam_equity_percentage:15.862042661123454
# aman_equity_percentage:15.281658132598478
# namita_equity_percentage:12.852052800434812
# vineeta_equity_percentage:12.542154161032869
# peyush_equity_percentage:30.117380069226584
# ghazal_equity_percentage:4.453005063266999

# %%
Total_equity=shark_tank["deal_equity"].sum()

# %% [markdown]
# #### Q15. Find the total number of amount invested in this show?

# %%
shark_tank["deal_amount"].sum()
# Out:
# 3742.00106

# %%
shark_tank[shark_tank["deal"]==1]["deal_amount"].sum()
# Out:
# 3742.00106
